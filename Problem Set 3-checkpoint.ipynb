# %% [markdown]
# # Question 1
#
# # Occupations

# %% [markdown]
#  # Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Step 2. Import the dataset from this address.

# %%
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep = '|')

# %% [markdown]
# # Step 3. Assign it to a variable called users

# %%
users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# # Step 4. Discover what is the mean age per occupation

# %%
users.groupby('occupation')["age"].mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# # Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
# create a function to convert M and F into integer 1 and 0
def gender_to_numeric(x):
    if x ==  'M':
        return 1
    if x == 'F':
        return 0

# %%
# apply the function to the gender column and create a new column "gender_n"
users['gender_n'] = users['gender'].apply(gender_to_numeric)

# %%
male_ratio = users.groupby('occupation').gender_n.sum() /users.occupation.value_counts() * 100
male_occupations = male_ratio.sort_values(ascending = False)
male_ratio.sort_values(ascending = False)
male_occupations
# Out:
# doctor           100.000000
# engineer          97.014925
# technician        96.296296
# retired           92.857143
# programmer        90.909091
# executive         90.625000
# scientist         90.322581
# entertainment     88.888889
# lawyer            83.333333
# salesman          75.000000
# educator          72.631579
# student           69.387755
# other             65.714286
# marketing         61.538462
# writer            57.777778
# none              55.555556
# administrator     54.430380
# artist            53.571429
# librarian         43.137255
# healthcare        31.250000
# homemaker         14.285714
# dtype: float64

# %% [markdown]
# # Step 6. For each occupation, calculate the minimum and maximum ages

# %%
print(users.groupby(['occupation'])['age'].agg(['min', 'max']))
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# # Step 7. For each combination of occupation and sex, calculate the mean age

# %%
print(users.groupby(['occupation', 'gender']).age.mean())
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# # Step 8. For each occupation present the percentage of women and men

# %%
gender_ocup = users.groupby(['occupation', 'gender']).agg({'gender': 'count'})

occup_count = users.groupby(['occupation']).count()

# divide the gender_ocup per the occup_count and multiply per 100
occup_gender = gender_ocup /occup_count * 100
occup_gender.loc[:, 'gender']
# Out:
# occupation     gender
# administrator  F          45.569620
#                M          54.430380
# artist         F          46.428571
#                M          53.571429
# doctor         M         100.000000
# educator       F          27.368421
#                M          72.631579
# engineer       F           2.985075
#                M          97.014925
# entertainment  F          11.111111
#                M          88.888889
# executive      F           9.375000
#                M          90.625000
# healthcare     F          68.750000
#                M          31.250000
# homemaker      F          85.714286
#                M          14.285714
# lawyer         F          16.666667
#                M          83.333333
# librarian      F          56.862745
#                M          43.137255
# marketing      F          38.461538
#                M          61.538462
# none           F          44.444444
#                M          55.555556
# ...

# %% [markdown]
# # Question 2 Euro Teams

# %% [markdown]
# # Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Step 2. Import the dataset from this address

# %%
euro12 = pd.read_csv(r'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')

# %% [markdown]
# # Step 3. Assign it to a variable called euro12

# %%
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# # Step 4. Select only the Goal column

# %%
euro12.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# # Step 5. How many team participated in the Euro2012?

# %%
print(euro12.shape[0])
# Out:
# 16

# %% [markdown]
# # Step 6. What is the number of columns in the dataset?

# %%
euro12.shape[1]
# Out:
# 35

# %% [markdown]
# # Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]

discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# # Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
card = euro12.groupby('Team').sum()
card = card.sort_values(['Red Cards', 'Yellow Cards'], ascending = False)
card.loc[:, ['Red Cards','Yellow Cards']]
# Out:
#                      Red Cards  Yellow Cards
# Team
# Greece                       1             9
# Poland                       1             7
# Republic of Ireland          1             6
# Italy                        0            16
# Portugal                     0            12
# Spain                        0            11
# Croatia                      0             9
# Czech Republic               0             7
# Sweden                       0             7
# France                       0             6
# Russia                       0             6
# England                      0             5
# Netherlands                  0             5
# Ukraine                      0             5
# Denmark                      0             4
# Germany                      0             4

# %% [markdown]
# # Step 9. Calculate the mean Yellow Cards given per Team

# %%
round(euro12['Yellow Cards'].mean())
# Out:
# 7

# %% [markdown]
# # Step 10. Filter teams that scored more than 6 goals

# %%
euro12[euro12.Goals>6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %% [markdown]
# # Step 11. Select the teams that start with G

# %%
euro12[euro12.Team.str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %% [markdown]
# # Step 12. Select the first 7 columns

# %%
euro12.iloc[:,:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# # Step 13. Select all columns except the last 3

# %%
euro12.iloc[:, :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# # Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
euro12.loc[euro12.Team.isin(['Englad', 'Italy', 'Russia']), ['Shooting Accuracy']]
# Out:
#    Shooting Accuracy
# 7              43.0%
# 12             22.5%

# %% [markdown]
# # Question 3 Housing

# %% [markdown]
# # Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Step 2. Create 3 differents Series, each of length 100, as follows:
# # • The first a random number from 1 to 4
# # • The second a random number from 1 to 3
# # • The third a random number from 10,000 to 30,000

# %%
# The first a random number from 1 to 4
H_data = np.random.randint(1,5,size=100)
series_1 = pd.DataFrame(H_data, columns=['random_number'])
print(series_1)
# Out:
#     random_number
# 0               3
# 1               1
# 2               2
# 3               3
# 4               2
# ..            ...
# 95              3
# 96              3
# 97              3
# 98              4
# 99              3
#
# [100 rows x 1 columns]

# %%
#The first a random number from 1 to 3
H_data = np.random.randint(1,3,size=100)
series_2 = pd.DataFrame(H_data, columns=['random_number'])
print(series_2)
# Out:
#     random_number
# 0               2
# 1               2
# 2               2
# 3               2
# 4               2
# ..            ...
# 95              1
# 96              2
# 97              2
# 98              1
# 99              2
#
# [100 rows x 1 columns]

# %%
# The third a random number from 10,000 to 30,000
H_data = np.random.randint(10000,30000,size=100)
series_3 = pd.DataFrame(H_data, columns=['random_number'])
print(series_3)
# Out:
#     random_number
# 0           26833
# 1           20672
# 2           17809
# 3           14602
# 4           25337
# ..            ...
# 95          21756
# 96          14644
# 97          29196
# 98          27567
# 99          28028
#
# [100 rows x 1 columns]

# %% [markdown]
# # Step 3. Create a DataFrame by joinning the Series by column

# %%
H_data= pd.concat([series_1, series_2 , series_3], axis=1)
print(H_data)
# Out:
#     random_number  random_number  random_number
# 0               3              2          26833
# 1               1              2          20672
# 2               2              2          17809
# 3               3              2          14602
# 4               2              2          25337
# ..            ...            ...            ...
# 95              3              1          21756
# 96              3              2          14644
# 97              3              2          29196
# 98              4              1          27567
# 99              3              2          28028
#
# [100 rows x 3 columns]

# %% [markdown]
# # Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
H_data.columns = ['bedrs', 'bathrs', 'price_sqr_meter']
print(H_data)
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       3       2            26833
# 1       1       2            20672
# 2       2       2            17809
# 3       3       2            14602
# 4       2       2            25337
# ..    ...     ...              ...
# 95      3       1            21756
# 96      3       2            14644
# 97      3       2            29196
# 98      4       1            27567
# 99      3       2            28028
#
# [100 rows x 3 columns]

# %% [markdown]
# # Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

# %%
H_data_new = H_data.bedrs.astype(str).str.cat( H_data.bathrs.astype(str)).str.cat( H_data.price_sqr_meter.astype(str))
H_data_new.columns = [ 'bigcolumn' ]

# %% [markdown]
# # Step 6. Ops it seems it is going only until index 99. Is it true?

# %%
print(H_data_new)
# Out:
# 0     3226833
# 1     1220672
# 2     2217809
# 3     3214602
# 4     2225337
#        ...
# 95    3121756
# 96    3214644
# 97    3229196
# 98    4127567
# 99    3228028
# Name: bedrs, Length: 100, dtype: object

# %% [markdown]
# # Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
H_data_new.reset_index()
H_data_new.reindex(index=range(0,299))
# Out:
# 0      3226833
# 1      1220672
# 2      2217809
# 3      3214602
# 4      2225337
#         ...
# 294        NaN
# 295        NaN
# 296        NaN
# 297        NaN
# 298        NaN
# Name: bedrs, Length: 299, dtype: object

# %% [markdown]
# # Question 4 Wind Statistics

# %% [markdown]
# # Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %% [markdown]
# # Step 2. Import the dataset from this address

# %%
data = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data' , sep='\s+',engine='python')

# %%
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %% [markdown]
# #  Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data["Date"] = pd.to_datetime(data[["Yr","Mo","Dy"]].astype(str).agg('-'.join, axis=1))
data = data.drop(columns=["Yr","Mo","Dy"])
data.head()
# Out:
#      RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL    CLO    BEL  \
# 0  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83  12.58  18.50
# 1  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79   9.67  17.54
# 2  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50   7.67  12.75
# 3  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83   5.88   5.46
# 4  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92  10.34  12.92
#
#      MAL       Date
# 0  15.04 2061-01-01
# 1  13.83 2061-01-02
# 2  12.71 2061-01-03
# 3  10.88 2061-01-04
# 4  11.83 2061-01-05

# %% [markdown]
# # Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it

# %%
data["Date"] = np.where(pd.DatetimeIndex(data["Date"]).year < 2000,data.Date,data.Date - pd.offsets.DateOffset(years=100))

# %%
data
# Out:
#         RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL    CLO  \
# 0     15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83  12.58
# 1     14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79   9.67
# 2     18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50   7.67
# 3     10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83   5.88
# 4     13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92  10.34
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04  14.00
# 6570  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25  18.05
# 6571  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50  16.42
# 6572  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46  12.12
# 6573  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58  11.38
#
#         BEL    MAL       Date
# 0     18.50  15.04 1961-01-01
# ...

# %% [markdown]
# # Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
newData = data.set_index("Date")
newData.index.astype("datetime64[ns]")
# Out:
# DatetimeIndex(['1961-01-01', '1961-01-02', '1961-01-03', '1961-01-04',
#                '1961-01-05', '1961-01-06', '1961-01-07', '1961-01-08',
#                '1961-01-09', '1961-01-10',
#                ...
#                '1978-12-22', '1978-12-23', '1978-12-24', '1978-12-25',
#                '1978-12-26', '1978-12-27', '1978-12-28', '1978-12-29',
#                '1978-12-30', '1978-12-31'],
#               dtype='datetime64[ns]', name='Date', length=6574, freq=None)

# %% [markdown]
# # Step 6. Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below.

# %%
count_null_value = newData.isna().sum().sum()
print(count_null_value)
# Out:
# 31

# %% [markdown]
# # Compute how many non-missing values there are in total.

# %%
count_notnull_value = newData.notnull().sum().sum()
print(count_notnull_value)
# Out:
# 78857

# %% [markdown]
# # Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# # A single number for the entire dataset.

# %%
y = newData.mean().mean()
y
# Out:
# 10.227982360836924

# %% [markdown]
# # Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
# # A different set of numbers for each location.

# %%
def math(x):
    x = pd.Series(x)
    Minimum = x.min()
    Maximum = x.max()
    Mean = x.mean()
    Std = x.std()
    result = [Minimum,Maximum,Mean,Std]
    index = ["Minimum","Maximum","Mean","Std"]
    result = pd.Series(result,index=index)
    return result
loc_stats = newData.apply(math)
loc_stats
# Out:
#                RPT        VAL        ROS        KIL        SHA        BIR  \
# Minimum   0.670000   0.210000   1.500000   0.000000   0.130000   0.000000
# Maximum  35.800000  33.370000  33.840000  28.460000  37.540000  26.160000
# Mean     12.362987  10.644314  11.660526   6.306468  10.455834   7.092254
# Std       5.618413   5.267356   5.008450   3.605811   4.936125   3.968683
#
#                DUB        CLA        MUL        CLO        BEL        MAL
# Minimum   0.000000   0.000000   0.000000   0.040000   0.130000   0.670000
# Maximum  30.370000  31.080000  25.880000  28.210000  42.380000  42.540000
# Mean      9.797343   8.495053   8.493590   8.707332  13.121007  15.599079
# Std       4.977555   4.499449   4.166872   4.503954   5.835037   6.699794

# %% [markdown]
# # Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# # A different set of numbers for each day.

# %%
day_stats = newData.apply(stats,axis=1)
day_stats
# Out:
#              Min    Max       Mean       Std
# Date
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356
# ...          ...    ...        ...       ...
# 1978-12-27  8.08  40.08  16.708333  7.868076
# 1978-12-28  5.00  41.46  15.150000  9.687857
# 1978-12-29  8.71  29.58  14.890000  5.756836
# 1978-12-30  9.13  28.79  15.367500  5.540437
# 1978-12-31  9.59  27.29  15.402500  5.702483
#
# [6574 rows x 4 columns]

# %% [markdown]
# # Step 11. Find the average windspeed in January for each location.
# # Treat January 1961 and January 1962 both as January.

# %%
january_data = newData[newData.index.month == 1]
print ("January windspeeds:")
print (january_data.mean())
# Out:
# January windspeeds:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# # Step 12. Downsample the record to a yearly frequency for each location.

# %%
print( "Yearly", newData.resample('A').mean())
# Out:
# Yearly                   RPT        VAL        ROS       KIL        SHA       BIR  \
# Date
# 1961-12-31  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962-12-31  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963-12-31  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-12-31  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-12-31  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966-12-31  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967-12-31  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968-12-31  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969-12-31  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970-12-31  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971-12-31  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %% [markdown]
# # Step 13. Downsample the record to a yearly frequency for each location.

# %%
print ("Monthly:", newData.resample('M').mean())
# Out:
# Monthly:                   RPT        VAL        ROS       KIL        SHA        BIR  \
# Date
# 1961-01-31  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02-28  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03-31  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-31   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...               ...        ...        ...       ...        ...        ...
# 1978-08-31   9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09-30  10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10-31   9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11-30  16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12-31  16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %% [markdown]
# # Step 14. Downsample the record to a weekly frequency for each location

# %%
print ("Weekly:", newData.resample('W').mean())
# Out:
# Weekly:                   RPT        VAL        ROS        KIL        SHA        BIR  \
# Date
# 1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN   9.870000
# 1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286   6.435714
# 1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
# 1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667   7.417143
# 1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857  14.828571
# ...               ...        ...        ...        ...        ...        ...
# 1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714   8.618571
# 1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143  12.774286
# 1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143   7.272857
# 1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714   6.290000
# 1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000   8.620000
#
# ...

# %% [markdown]
# # Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks

# %%
first_year = newData[newData.index.year == 1961]
stats1 = newData.resample('W').mean().apply(lambda x: x.describe())
print (stats1)
# Out:
#               RPT         VAL         ROS         KIL         SHA         BIR  \
# count  940.000000  940.000000  940.000000  940.000000  939.000000  940.000000
# mean    12.365304   10.647725   11.661255    6.309334   10.455607    7.094787
# std      3.466600    3.372501    2.840361    2.186432    3.146715    2.556633
# min      3.874286    2.452857    4.901429    1.447143    2.775714    1.382857
# 25%      9.884286    8.277857    9.613929    4.742857    8.248571    5.211071
# 50%     12.291429   10.486429   11.490000    6.165714   10.254286    6.933571
# 75%     14.547143   12.757857   13.457143    7.584286   12.627143    8.842500
# max     24.010000   23.715714   21.384286   14.517143   22.897143   16.010000
#
#               DUB         CLA         MUL         CLO         BEL         MAL
# count  940.000000  940.000000  940.000000  940.000000  940.000000  940.000000
# mean     9.801271    8.496123    8.496452    8.710639   13.125912   15.597171
# ...

# %% [markdown]
# # Question 5

# %% [markdown]
# # Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Step 2. Import the dataset from this address

# %%
chipo = pd.read_csv(r'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', delimiter= '\t',engine = 'python')

# %% [markdown]
# # Step 3. Assign it to a variable called chipo.

# %%
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# # Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# # Step 5. What is the number of observations in the dataset?

# %%
chipo.shape[0]
# Out:
# 4622

# %% [markdown]
# # Step 6. What is the number of columns in the dataset?

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# # Step 7. Print the name of all the columns.

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# # Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# # Step 9. Which was the most-ordered item?

# %%
chipo.item_name.value_counts().head(1)
# Out:
# Chicken Bowl    726
# Name: item_name, dtype: int64

# %% [markdown]
# # Step 10. For the most-ordered item, how many items were ordered?

# %%
chipo.item_name.unique().shape[0]
# Out:
# 50

# %% [markdown]
# # Step 11. What was the most ordered item in the choice_description column?

# %%
chipo.choice_description.value_counts().head()
# Out:
# [Diet Coke]                                                                          134
# [Coke]                                                                               123
# [Sprite]                                                                              77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]     40
# Name: choice_description, dtype: int64

# %% [markdown]
# # Step 12. How many items were orderd in total?

# %%
chipo.quantity.sum()
# Out:
# 4972

# %% [markdown]
# # Step 13.
# • Turn the item price into a float
# • Check the item price type
# • Create a lambda function and change the type of item price
# • Check the item price type

# %%
def num_float(x):
    return float(x[1:-1])

# %%
chipo.item_price = chipo.item_price.apply(num_float)

# %% [markdown]
# # Step 14. How much was the revenue for the period in the dataset?

# %%
chipo.item_price.sum()
# Out:
# 34500.16

# %% [markdown]
# # Step 15. How many orders were made in the period?

# %%
chipo.order_id.value_counts().count()
# Out:
# 1834

# %% [markdown]
# # Step 16. What is the average revenue amount per order?

# %%
order_grouped = chipo.groupby(by=['order_id']).sum()
order_grouped['quantity'].mean()
# Out:
# 2.711014176663032

# %% [markdown]
# # Step 17. How many different items are sold?

# %%
chipo['unit_price'] = (chipo['item_price'] / chipo['quantity'])
new = chipo[['item_name', 'choice_description', 'unit_price']]
new.sort_values(by='unit_price', ascending=False)
# Out:
#                 item_name                                 choice_description  \
# 2442  Barbacoa Salad Bowl  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...
# 2957     Steak Salad Bowl  [Fresh Tomato Salsa, [Black Beans, Cheese, Gua...
# 613      Steak Salad Bowl  [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 2401     Steak Salad Bowl  [Fresh Tomato Salsa, [Fajita Vegetables, Guaca...
# 281      Steak Salad Bowl  [Tomatillo Red Chili Salsa, [Black Beans, Chee...
# ...                   ...                                                ...
# 378           Canned Soda                                     [Mountain Dew]
# 1805          Canned Soda                                           [Sprite]
# 2520          Canned Soda                                        [Coca Cola]
# 2981        Bottled Water                                                NaN
# 646           Canned Soda                                           [Sprite]
#
#       unit_price
# 2442       11.89
# ...

# %% [markdown]
# # Question 6
# Create a line plot showing the number of marriages and divorces per capita in the
# U.S. between 1867 and 2014. Label both lines and show the legend.
# Don't forget to label your axes!

# %%
import pandas as pd

us_marriage_divorce_data = pd.read_csv('C:/Users/sarbj/Downloads/us-marriages-divorces-1867-2014.csv')

# %%
us_marriage_divorce_data
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0    1867   357000.0   10000.0    36970000                 9.7
# 1    1868   345000.0   10000.0    37885000                 9.1
# 2    1869   348000.0   11000.0    38870000                 9.0
# 3    1870   352000.0   11000.0    39905000                 8.8
# 4    1871   359000.0   12000.0    41010000                 8.8
# ..    ...        ...       ...         ...                 ...
# 140  2007  2197000.0  856000.0   301696000                 7.3
# 141  2008  2157000.0  844000.0   304543000                 7.1
# 142  2009  2080000.0  840000.0   307240000                 6.8
# 143  2010  2096000.0  872000.0   309776000                 6.8
# 144  2011  2118000.0  877000.0   312034000                 6.8
#
#      Divorces_per_1000
# 0                  0.3
# 1                  0.3
# 2                  0.3
# 3                  0.3
# 4                  0.3
# ..                 ...
# 140                2.8
# ...

# %%
import matplotlib.pyplot as plt

years = us_marriage_divorce_data['Year'].values
marriages = us_marriage_divorce_data['Marriages_per_1000'].values
divorces = us_marriage_divorce_data['Divorces_per_1000'].values

plt.figure()
plt.plot(years, divorces, label='Divorces')
plt.plot(years, marriages , label = 'Marriages')
plt.xlabel('Years')
plt.ylabel('Capita')
plt.legend(loc='upper left')
plt.title("US Marriages and Divorces")
# Out:
# Text(0.5, 1.0, 'US Marriages and Divorces')

# %% [markdown]
# # Question 7
# Create a vertical bar chart comparing the number of marriages and divorces per
# capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!

# %%
import pandas as pd

us_marriage_divorce_data = pd.read_csv('C:/Users/sarbj/Downloads/us-marriages-divorces-1867-2014.csv')

# %%
us_marriage_divorce_data
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0    1867   357000.0   10000.0    36970000                 9.7
# 1    1868   345000.0   10000.0    37885000                 9.1
# 2    1869   348000.0   11000.0    38870000                 9.0
# 3    1870   352000.0   11000.0    39905000                 8.8
# 4    1871   359000.0   12000.0    41010000                 8.8
# ..    ...        ...       ...         ...                 ...
# 140  2007  2197000.0  856000.0   301696000                 7.3
# 141  2008  2157000.0  844000.0   304543000                 7.1
# 142  2009  2080000.0  840000.0   307240000                 6.8
# 143  2010  2096000.0  872000.0   309776000                 6.8
# 144  2011  2118000.0  877000.0   312034000                 6.8
#
#      Divorces_per_1000
# 0                  0.3
# 1                  0.3
# 2                  0.3
# 3                  0.3
# 4                  0.3
# ..                 ...
# 140                2.8
# ...

# %%
us_marriage_divorce_data_yearly = us_marriage_divorce_data[us_marriage_divorce_data['Year'].apply(lambda x: x in [1900, 1950, 2000])]

# %%
us_marriage_divorce_data_yearly
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 33   1900   709000.0   56000.0    76094000                 9.3
# 83   1950  1667000.0  385000.0   151684000                11.0
# 133  2000  2315000.0  944000.0   282398000                 8.2
#
#      Divorces_per_1000
# 33                 0.7
# 83                 2.5
# 133                3.3

# %%
import matplotlib.pyplot as plt

years = us_marriage_divorce_data_yearly['Year'].values
marriages = us_marriage_divorce_data_yearly['Marriages_per_1000'].values
divorces = us_marriage_divorce_data_yearly['Divorces_per_1000'].values
plt.figure()


plt.bar(years -4 , marriages ,color='blue',
        edgecolor='black',
        width=8,
        align='center',
        label='Divorces')
plt.bar(years +4, divorces,color='orange',
        edgecolor='black',
        width=8,
        align='center',
        label='Marriges')

plt.xlabel('Years')
plt.ylabel('Capita')
plt.legend()
plt.title("US Marriages and Divorces of years")
# Out:
# Text(0.5, 1.0, 'US Marriages and Divorces of years')

# %% [markdown]
# # Question 8
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort
# the actors by their kill count and label each bar with the corresponding actor's name.
# Don't forget to label your axes!

# %%
import pandas as pd
import numpy as np

hollywood_actor_kills = pd.read_csv('C:/Users/sarbj/Downloads/actor_kill_counts.csv')

# %%
hollywood_actor_kills
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 2         Clint Eastwood    207
# 3             Clive Owen    194
# 4         Dolph Lundgren    239
# 5                 Jet Li    201
# 6           Nicolas Cage    204
# 7     Sylvester Stallone    267
# 8    Tomisaburo Wakayama    226
# 9          Wesley Snipes    193

# %%
actor_names = hollywood_actor_kills['Actor'].values
kill_counts = hollywood_actor_kills['Count'].values
plt.figure()
colours = ['#C4E57D','#2AC280','#FFAE39','#DC5B3B','#52E397','#C5CBA3','#9CD5F6','#6E50D9','#9A5E59','#9BC8F5','#0BBC66',
           '#FF3D52','#3B19CE','#25974F','#1EAD79','#375E4C','#43C711','#A4CCD9','#AFF373','#392D6A','#792D86','#9CA54B',
           '#7F03BE','#D5EC95','#FCE2A5']
plt.barh(actor_names,kill_counts, color=colours,edgecolor='black',height= 0.7, align='center')
plt.title("Deadlist of actors in Hollywood")
plt.xlabel('Counts')
plt.ylabel('Actor Name')
# Out:
# Text(0, 0.5, 'Actor Name')

# %% [markdown]
# # Question 9
# Create a pie chart showing the fraction of all Roman Emperors that were
# assassinated.
# Make sure that the pie chart is an even circle, labels the categories, and shows the
# percentage breakdown of the categories.

# %%
import pandas as pd
import numpy as np

roman_emperors = pd.read_csv('C:/Users/sarbj/Downloads/roman-emperor-reigns.csv')
roman_emperors
# Out:
#            Emperor  Length_of_Reign         Cause_of_Death
# 0         Augustus            40.58  Possibly assassinated
# 1         Tiberius            22.50  Possibly assassinated
# 2         Caligula             4.83           Assassinated
# 3         Claudius            13.75  Possibly assassinated
# 4             Nero            13.67                Suicide
# ..             ...              ...                    ...
# 63   Valentinian I            11.00         Natural causes
# 64          Valens            14.00       Killed in battle
# 65         Gratian            16.00           Assassinated
# 66  Valentinian II            17.00  Possibly assassinated
# 67    Theodosius I            16.00         Natural causes
#
# [68 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

assassinated_emperors = roman_emperors[roman_emperors['Cause_of_Death'].apply(lambda x: 'assassinated' in x.lower())]
assassinated_emperors
# Out:
#                Emperor  Length_of_Reign         Cause_of_Death
# 0             Augustus            40.58  Possibly assassinated
# 1             Tiberius            22.50  Possibly assassinated
# 2             Caligula             4.83           Assassinated
# 3             Claudius            13.75  Possibly assassinated
# 5                Galba             0.58           Assassinated
# 7            Vitellius             0.67           Assassinated
# 10            Domitian            15.00           Assassinated
# 17            Commodus            15.00           Assassinated
# 18            Pertinax             0.25           Assassinated
# 21           Caracalla            19.00           Assassinated
# 22                Geta             3.00           Assassinated
# 24          Elagabalus             3.75           Assassinated
# 25   Severus Alexander            13.00           Assassinated
# 26         Maximinus I             3.25           Assassinated
# ...

# %%
import matplotlib.pyplot as plt
number_assassinated = len(assassinated_emperors)
other_deaths = len(roman_emperors) - number_assassinated

# %%
chart_values = [number_assassinated,other_deaths]
chart_values
# Out:
# [30, 38]

# %%
colours = ['#FF3D52','#25974F','#1EAD79','#375E4C','#43C711','#A4CCD9','#7F03BE','#D5EC95','#FCE2A5'] 
plt.figure(figsize=(5, 5))
plt.pie(pie_chart,colors=colours, labels=['Number Assassinated', 'Other Deaths'],startangle=80,autopct='%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x20593857ee0>,
# ...
#  [Text(-1.0297449409813628, 0.38681436959256027, 'Number Assassinated'),
#   Text(1.029744940981363, -0.38681436959255955, 'Other Deaths')],
#  [Text(-0.5616790587171069, 0.21098965614139648, '44.12'),
#   Text(0.5616790587171071, -0.2109896561413961, '55.88')])

# %% [markdown]
# # Question 10
# Create a scatter plot showing the relationship between the total revenue earned by
# arcades and the number of Computer Science PhDs awarded in the U.S. between
# 2000 and 2009.
# Don't forget to label your axes!
# Color each dot according to its year

# %%
import pandas as pd
import numpy as np

arcade_revenue_cs_doctorates = pd.read_csv('C:/Users/sarbj/Downloads/arcade-revenue-vs-cs-doctorates.csv')
arcade_revenue_cs_doctorates
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
# 5  2005                            1.435
# 6  2006                            1.601
# 7  2007                            1.654
# 8  2008                            1.803
# 9  2009                            1.734
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948
# 5                                      1129
# 6                                      1453
# 7                                      1656
# 8                                      1787
# 9                                      1611

# %%
import matplotlib.pyplot as plt
arcade_revenue = arcade_revenue_cs_doctorates['Total Arcade Revenue (billions)'].values
cs_doctorates_awarded = arcade_revenue_cs_doctorates['Computer Science Doctorates Awarded (US)'].values

# %%
categories = np.array([0,2,1,1,1,2,0,0,2,1])
colormap = np.array(['r','g','b'])
plt.figure()
plt.scatter( arcade_revenue,cs_doctorates_awarded,c=colormap[categories], s=40, marker='d', edgecolor='black')        
plt.xlabel('Total Arcade Revenue (billions)')
plt.ylabel('Computer Science Doctorates Awarded (US)')
# Out:
# Text(0, 0.5, 'Computer Science Doctorates Awarded (US)')
